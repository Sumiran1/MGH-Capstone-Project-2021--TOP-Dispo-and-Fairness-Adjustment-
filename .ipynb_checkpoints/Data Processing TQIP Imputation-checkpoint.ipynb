# %% [markdown]
# ## Imports

# %%
# using Pkg
# Pkg.add("CategoricalArrays")
# Pkg.add("DataFramesMeta")
using Random, CategoricalArrays, DataFrames, DataFramesMeta, StatsBase, CSV

# %% [markdown]
# ## Master Imputation Function

# %%
function impute_missing_data(train, test)
    # Dropped tmode1 and hemorrhage_ctrl_type and severity_max (29/11/2019)
    # and alcohol (09/01/2020) and acslevel (01/02/2020)
    names = [
        :age, :gender, :race1, :signsoflife, :sbp1, :pulse1,
        :oxysat1, :temp1, :gcstot1, :bleeding_disorder, :current_chemotherapy,
        :congestive_heart_failure, :current_smoker, :chronic_renal_failure,
        :history_cva, :diabetes, :disseminated_cancer,  :copd, :steroid,
        :cirrhosis, :history_MI, :history_pvd, :hypertension_medication,
        :method_of_injury, :Head_severity, :Face_severity, :Neck_severity, :Thorax_severity, :Abdomen_severity,
        :Spine_severity, :Upper_Extremity_severity, :Lower_Extremity_severity,
        :Pelvis_Perineum_severity, :External_severity,
        #:severity_max, #:hemorrhage_ctrl_type, #:alcohol, #:tmode1, #:acslevel
    ]
    
    inc_keys_train = train[!, :inc_key]
    train = train[!, names]
    inc_keys_test = test[!, :inc_key]
    test = test[!, names]
    n_train = nrow(train)
    X = vcat(train, test)
    n_total = nrow(X)

    k_neighbors = 200
    Fitting OptImpute on train+test set at the same time (no y variable)
    lnr_optimpute_train = IAI.ImputationLearner(method=:opt_knn, knn_k=k_neighbors, cluster=true)
    IAI.fit!(lnr_optimpute_train, X)
    X = IAI.transform(lnr_optimpute_train, X)
    train_return = X[1:n_train, :]
    train_return = hcat(train_return, inc_keys_train)
    test_return = X[n_train+1:n_total, :]
    test_return = hcat(test_return, inc_keys_test)
    
    return train_return, test_return
end
# Out:
# impute_missing_data (generic function with 1 method)

# %% [markdown]
# ## Blunt

# %%
data_path_blunt = "C:/Users/15125/Desktop/CAPSTONE PROJECT/CLEANED DATA/POST PRE PROCESSING/blunt/"
blunt_train =  CSV.read(data_path_blunt*"X_train_pre_process_blunt.csv")
blunt_test = CSV.read(data_path_blunt*"X_test_pre_process_blunt.csv")
imputed_blunt_train, imputed_blunt_test= impute_missing_data(blunt_train, blunt_test)
CSV.write("C:/Users/15125/Desktop/CAPSTONE PROJECT/CLEANED DATA/POST IMPUTATION/blunt/blunt_imputed_train.csv"
    ,imputed_blunt_train)
CSV.write("C:/Users/15125/Desktop/CAPSTONE PROJECT/CLEANED DATA/POST IMPUTATION/blunt/blunt_imputed_test.csv"
    ,imputed_blunt_test)
# Out:
# Imputing clusters...                 0%|█               |  ETA: N/A
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:39:00
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 1:01:18
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:57:25
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:49:44
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:54:36
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:02
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:59:10
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 1:01:18
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 1:01:46
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:59:19
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 1:00:03
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 1:00:20
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:59:06
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:56:41
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:54:51
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:52:53
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:51:59
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:50:43
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:50:17
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:50:33
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 0%|█               |  ETA: 0:49:10
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:55
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:48:41
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:48:40
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:43
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:46:43
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:46:06
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:45:51
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:45:13
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:45:56
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:02
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:05
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:21
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:30
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:24
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:09
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:02
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:01
# Imputing clusters...                 1%|█               |  ETA: 0:49:28
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:49:11
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:48:35
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:48:27
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:56
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:47:21
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:46:45
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:46:11
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:45:52
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:45:46
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:45:16
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:56
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:33
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:31
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:41
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:19
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:09
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:43:52
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:43:33
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:09
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:12
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:23
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:44:02
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:43:58
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:43:53
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:43:37
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:43:32
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 1%|█               |  ETA: 0:43:19
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:58
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:41
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:38
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:36
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:52
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:45
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:40
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:33
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:26
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:17
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:22
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:08
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:12
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:21
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:27
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:11
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:26
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:12
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:19
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:11
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:42:01
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:51
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:51
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:36
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:32
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:30
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:29
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:17
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:21
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:10
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:05
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:40:53
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:40:49
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:40:57
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:40:59
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:03
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:10
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:41:01
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:40:56
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:40:51
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:40:48
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 2%|█               |  ETA: 0:40:48
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:50
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:41
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:38
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:43
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:37
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:33
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:27
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:17
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:08
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:00
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:39:54
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:03
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:14
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:05
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:10
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:11
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:15
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:20
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                 3%|█               |  ETA: 0:40:10
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# ...
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:23
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:22
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:22
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:21
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:21
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:20
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:20
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:19
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:19
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:18
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:18
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:17
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:16
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:16
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:15
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:15
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:14
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:14
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:13
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:13
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:12
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:12
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:11
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...                99%|████████████████|  ETA: 0:00:11
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:10
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:10
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:09
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:09
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:08
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:08
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:07
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:07
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:06
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:06
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:05
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:05
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:04
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:04
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:03
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:03
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:02
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:02
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████|  ETA: 0:00:01
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     17%|███             |  ETA: 0:00:02
# 4m  Warmstart:  rand
#
# Trying different warm starts...     33%|██████          |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     50%|█████████       |  ETA: 0:00:01
# 4m  Warmstart:  rand
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...     83%|██████████████  |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:01
# Imputing clusters...               100%|████████████████|  ETA: 0:00:01
# Trying different warm starts...      0%|█               |  ETA: N/A
# 4m  Warmstart:  knn
#
# Trying different warm starts...     67%|███████████     |  ETA: 0:00:00
# 4m  Warmstart:  rand
#
# Trying different warm starts...    100%|████████████████| Time: 0:00:00
# Imputing clusters...               100%|████████████████| Time: 0:35:44
# "C:/Users/15125/Desktop/CAPSTONE PROJECT/CLEANED DATA/POST IMPUTATION/blunt/blunt_imputed_test.csv"

# %% [markdown]
# ## Penetrating

# %%
data_path_penetrating = "C:/Users/15125/Desktop/CAPSTONE PROJECT/CLEANED DATA/POST PRE PROCESSING/penetrating/"
penetrating_train = CSV.read(data_path_penetrating*"X_train_pre_process_penetrating.csv")
penetrating_test = CSV.read(data_path_penetrating*"X_test_pre_process_penetrating.csv")

println(nrow(penetrating_train) + nrow(penetrating_test))
imputed_penetrating_train, imputed_penetrating_test= impute_missing_data(penetrating_train, penetrating_test)
CSV.write("C:/Users/15125/Desktop/CAPSTONE PROJECT/CLEANED DATA/POST IMPUTATION/penetrating/penetrating_imputed_train.csv"
    ,imputed_penetrating_train)
CSV.write("C:/Users/15125/Desktop/CAPSTONE PROJECT/CLEANED DATA/POST IMPUTATION/penetrating/penetrating_imputed_test.csv"
    ,imputed_penetrating_test)
# Out:
# 87412
# 87412
# UndefVarError: train_return not defined
#
# Stacktrace:
#  [1] impute_missing_data(::DataFrame, ::DataFrame) at .\In[9]:35
#  [2] top-level scope at In[12]:6
